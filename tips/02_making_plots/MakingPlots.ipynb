# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,4*np.pi, 500)
y = np.sin(x)

# %%
fig = plt.figure(figsize=(3.54,3.54), dpi=200)
plt.plot(x, y, linewidth=2)
plt.xlabel('X label (s)', fontsize=20)
plt.ylabel('Y label (V)', fontsize=10)
plt.savefig('test.png')

# %%
fig = plt.figure(figsize=(3.54,3.54), dpi=300)

# %%
import matplotlib 
matplotlib.rc('xtick', labelsize=10) 
matplotlib.rc('ytick', labelsize=10) 

fig = plt.figure(figsize=(3.54,3.54), dpi=300)
plt.plot(x, y, linewidth=2)
plt.xlabel('X label (s)', fontsize=15)
plt.ylabel('Y label (V)', fontsize=15)
plt.savefig('300dpi.png', bbox_inches='tight')

# %%
import matplotlib 
matplotlib.rc('xtick', labelsize=10) 
matplotlib.rc('ytick', labelsize=10) 

fig = plt.figure(figsize=(7.25,3.54), dpi=600)
plt.plot(x, y, linewidth=2)
plt.xlabel('X label (s)', fontsize=15)
plt.ylabel('Y label (V)', fontsize=15)
plt.savefig('600dpi-full.png', bbox_inches='tight')

# %%
import matplotlib 
matplotlib.rc('xtick', labelsize=16) 
matplotlib.rc('ytick', labelsize=16) 

fig = plt.figure(figsize=(5,3), dpi=96)
plt.plot(x, y, linewidth=2)
plt.xlabel('X label (s)', fontsize=18)
plt.ylabel('Y label (V)', fontsize=18)
plt.savefig('presentation.png', bbox_inches='tight')

# %%
import matplotlib 
matplotlib.rc('xtick', labelsize=16) 
matplotlib.rc('ytick', labelsize=16) 

fig = plt.figure(figsize=(13.33,7.5), dpi=96)
plt.plot(x, y, linewidth=2)
plt.xlabel('X label (s)', fontsize=18)
plt.ylabel('Y label (V)', fontsize=18)
plt.savefig('presentation-full.eps', bbox_inches='tight')
